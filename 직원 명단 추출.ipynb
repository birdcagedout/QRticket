# %%
import pandas as pd

# %%
# 노원구청 - 페이지당 행개수 = 2000개

url = 'https://www.nowon.kr/www/user/orgnzt/BD_selectOrgnztList.do?q_deptCode=&q_searchTy=&q_searchVal=&q_rowPerPage=1800&q_currPage=1&q_sortName=&q_sortOrder='

# %%
# pandas.read_html
# 지정한 홈페이지 주소에 있는 테이블()들을 DataFrame의 List로 반환
df = pd.read_html(url, header=0)[0]

# %%
df
# Out:
#        이름           부서/팀      직위  \
# 0     오승록           노원구청     구청장
# 1     김인철           노원구청    부구청장
# 2     최미숙          행정지원국  행정지원국장
# 3     김명수          행정지원국  지가조사팀장
# 4     김영범          행정지원국    계약팀장
# ...   ...            ...     ...
# 1709  성은경  상계10동 / 복지지원팀  복지지원팀장
# 1710  전민지  상계10동 / 복지지원팀     주무관
# 1711  윤철상  상계10동 / 복지지원팀     주무관
# 1712  김진곤  상계10동 / 복지지원팀     주무관
# 1713  김은미  상계10동 / 복지지원팀     주무관
#
#                                                      업무          전화번호
# 0                                                   구청장  02-2116-3001
# 1                                                  부구청장  02-2116-3012
# 2                                            행정지원국 업무총괄  02-2116-3013
# 3                     ○ 개별공시지가 조사팀 업무 총괄○ 부동산가격공시위원회 운영  02-2116-3639
# 4                                             계약팀 업무 총괄  02-2116-3469
# ...                                                 ...           ...
# ...

# %%
df.to_excel("전직원명단_202201.xlsx")
